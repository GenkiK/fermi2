# %% [markdown]
# ## $\frac{1}{\sqrt{kT_e}}$を衝突(脱)励起に考慮してから

# %%
from fermi_model import *

ne_lst = [100000, 10, 0.1, 0.001]
Te_lst = [0.1, 0.5, 1, 5, 10, 50]
for Te in Te_lst:
    print(f"Te = {Te}")
    plots_percentage_fluxes(ne_lst, Te=Te)
    print("==============================================================================", end="\n\n")
# Out:
# Te = 0.1
# ==============================================================================
#
# Te = 0.5
# ==============================================================================
#
# Te = 1
# ==============================================================================
#
# Te = 5
# ==============================================================================
#
# Te = 10
# ==============================================================================
#
# Te = 50
# c:\Users\GenkiKinoshita\Desktop\git_rep\fermi\20210329\notebooks\fermi_model.py:89: RuntimeWarning: divide by zero encountered in double_scalars
#   eigen = np.dot(y, y) / np.dot(y, x)
# ==============================================================================

# %% [markdown]
# ## ほしい値のみ

# %%
from fermi_model import *

ne_lst = [100, 10, 1]
Te_lst = [0.05, 0.075, 0.1, 0.3, 0.5, 0.75]
for Te in Te_lst:
    print(f"Te = {Te}")
    plots_percentage_fluxes(ne_lst, Te=Te)
    print("==============================================================================", end="\n\n")
# Out:
# Te = 0.05
# ==============================================================================
#
# Te = 0.075
# ==============================================================================
#
# Te = 0.1
# ==============================================================================
#
# Te = 0.3
# ==============================================================================
#
# Te = 0.5
# ==============================================================================
#
# Te = 0.75
# ==============================================================================

# %%
print(fr"現実的な kTe 範囲は")
3 / (4 * np.pi ** 2), 15 / (2 * np.pi ** 2)
# Out:
# 現実的な kTe 範囲は
# (0.07599088773175333, 0.7599088773175333)

# %% [markdown]
# ##

# %% [markdown]
# ## 電子数10の時

# %%
from fermi_model import *

ne_lst = [100, 10, 1]
Te_lst = [0.05, 0.075, 0.1, 0.3, 0.5, 0.75]
for Te in Te_lst:
    print(f"Te = {Te}")
    plots_percentage_fluxes(ne_lst, Te=Te, num=10)
    print("==============================================================================", end="\n\n")
# Out:
# Te = 0.05
# ==============================================================================
#
# Te = 0.075
# ==============================================================================
#
# Te = 0.1
# ==============================================================================
#
# Te = 0.3
# ==============================================================================
#
# Te = 0.5
# ==============================================================================
#
# Te = 0.75
# ==============================================================================

# %% [markdown]
# ## $\frac{1}{\sqrt{kT_e}}$を衝突(脱)励起に考慮してから

# %% [markdown]
# ## ほしい値だけ

# %%
from fermi_model import * 

ne_lst = [1000000, 100, 10, 1]
Te_lst = [0.05, 0.075, 0.1, 0.3, 0.5, 0.75]
for Te in Te_lst:
    plots_mean_dist(ne_lst=ne_lst, Te=Te, include_equ=False, figsize=(8, 5))
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
from fermi_model import * 

ne_lst = [100000, 10, 0.1, 0.001, 0.0001]
Te_lst = [0.1, 0.5, 1, 5, 10, 50]
for Te in Te_lst:
    plots_mean_dist(ne_lst=ne_lst, Te=Te, include_equ=False, figsize=(8, 5))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\GenkiKinoshita\Desktop\git_rep\fermi\20210329\notebooks\fermi_model.py:89: RuntimeWarning: divide by zero encountered in double_scalars
#   eigen = np.dot(y, y) / np.dot(y, x)
