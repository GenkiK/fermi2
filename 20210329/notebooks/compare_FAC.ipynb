# %%
# %matplotlib inline
from fermi_model import *

# %%
ne_lst = np.array([ 0.10023097,  0.10023097, 10.02309686, 10.02309686])
Te_lst = np.array([1,2,1,2])

# %%
for ne, Te in zip(ne_lst, Te_lst):
    plot_population_and_mean_distribution(ne=ne, Te=Te, e_num=3)

# %%
for ne, Te in zip(ne_lst, Te_lst):
    plot_population_and_mean_distribution(ne=ne, Te=Te, e_num=3, ylim=(1e-20, 10))

# %%
for ne, Te in zip(ne_lst, Te_lst):
    plots_percentage_fluxes(ne_lst=[ne], Te=Te, e_num=3)

# %%
for ne, Te in zip(ne_lst, [100, 1000, 100, 1000]):
    plots_percentage_fluxes(ne_lst=[ne], Te=Te, e_num=3)

# %%
ne_original_lst = ne_lst / 1.068e-14 * 106553.894

# %%
# ■に対応する
def eps2eV(val_eps: float, t=1):
    return val_eps * t

# ▲に対応する
def eV2eps(val_eV: float, t=1):
    return val_eV / t

# %%
ne_original_lst
# Out:
# array([1.00000001e+18, 1.00000001e+18, 1.00000000e+20, 1.00000000e+20])

# %%
import numpy as np

# %%
3 / (400 * np.pi**2) * 10 * 1000
# Out:
# 7.599088773175334

# %%
ne_lst_1000 = [eV2eps(elem, t=1000) * 1.068e-14 / 106553.894 for elem in ne_original_lst]
Te_lst_1000 = [eV2eps(elem, t=1000) * 1000 for elem in Te_lst] # 仮にeV/eps = 1000になったとしても、その考えている系ではTeが1keVとかなので、結局今まで考えてたモデルでのTe[ε]は1くらいのオーダーのまま
ne_lst_1000, Te_lst_1000
# Out:
# ([0.00010023096856507186,
#   0.00010023096856507186,
#   0.010023096856507187,
#   0.010023096856507187],
#  [1.0, 2.0, 1.0, 2.0])
